# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# Generate synthetic data
X, labels_true = make_blobs(n_samples=300, centers=4, cluster_std=0.5, random_state=0)

# Standardize the data
X = StandardScaler().fit_transform(X)

# Visualize the data
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.title("Generated Data Points")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
# Apply DBSCAN clustering
db = DBSCAN(eps=0.3, min_samples=10).fit(X)
labels = db.labels_

# Create mask to identify core samples
core_samples_mask = np.zeros_like(labels, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True

# Evaluate clustering
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
print(f"Estimated number of clusters: {n_clusters}")
print("Silhouette Score:", metrics.silhouette_score(X, labels))
# Out:
# Estimated number of clusters: 4
# Silhouette Score: 0.6899598627352681
